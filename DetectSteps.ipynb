# %% [markdown]
# <a href="https://colab.research.google.com/github/Evgen-Shah/YOLOV5_WORKS/blob/main/DetectSteps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import imutils
from google.colab import drive
drive.mount('/content/drive')
from google.colab import files
from IPython.display import display
import cv2
from PIL import Image
from io import BytesIO
from PIL import Image
import numpy as np
import requests
from google.colab.patches import cv2_imshow
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/contentStairs/yolov5/train.py --img 640 --batch 16 --epochs 400 --data /content/drive/MyDrive/contentStairs/yolov5/data/custom_date.yaml --weights /content/drive/MyDrive/contentStairs/yolov5/yolov5s.pt --cache
# Out:
# train: weights=/content/drive/MyDrive/contentStairs/yolov5/yolov5s.pt, cfg=, data=/content/drive/MyDrive/contentStairs/yolov5/data/custom_date.yaml, hyp=drive/MyDrive/contentStairs/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=400, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=drive/MyDrive/contentStairs/yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 63 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-69-g7830e91 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %% [markdown]
# Батчи, которые использовались для обучения

# %%
ai = Image.open("/content/drive/MyDrive/contentStairs/yolov5/runs/train/exp10/train_batch0.jpg")
display(ai)
ai = Image.open("/content/drive/MyDrive/contentStairs/yolov5/runs/train/exp10/train_batch1.jpg")
display(ai)
ai = Image.open("/content/drive/MyDrive/contentStairs/yolov5/runs/train/exp10/train_batch2.jpg")
display(ai)

# %% [markdown]
# prediction изображение

# %%
path="/content/drive/MyDrive/contentStairs/yolov5/runs/train/exp10"
ai = Image.open(path+'/val_batch0_pred.jpg')
display(ai)

# %%
# !python /content/drive/MyDrive/contentStairs/yolov5/detect.py --weights /content/drive/MyDrive/contentStairs/yolov5/runs/train/exp10/weights/last.pt --img 640 --conf 0.3 --source /content/drive/MyDrive/contentStairs/yolov5/data/images --save-txt
# Out:
# detect: weights=['/content/drive/MyDrive/contentStairs/yolov5/runs/train/exp10/weights/last.pt'], source=/content/drive/MyDrive/contentStairs/yolov5/data/images, data=drive/MyDrive/contentStairs/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=drive/MyDrive/contentStairs/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-69-g7830e91 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/12 /content/drive/MyDrive/contentStairs/yolov5/data/images/1.jpg: 640x480 13 stairss, Done. (0.030s)
# image 2/12 /content/drive/MyDrive/contentStairs/yolov5/data/images/10.jpg: 448x640 12 stairss, Done. (0.028s)
# ...

# %% [markdown]
# Выведем полученные результаты

# %% [markdown]
# # Детекция при conf = 0.5

# %%
import os.path
path="/content/drive/MyDrive/contentStairs/yolov5/runs/detect/exp"
for i in range (1,13):
  print('Число ступеней ' + str(sum(1 for line in open(path+'/labels/' + str(i) +'.txt', 'r'))))
  image = Image.open(path+'/'+str(i)+'.jpg')
  image = np.array(image)
  image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  cv2_imshow(image)

# %% [markdown]
# Детекция при conf = 0.5, некоторые ступени были не определены

# %% [markdown]
# # Детекция при conf = 0.3

# %%
import os.path
path="/content/drive/MyDrive/contentStairs/yolov5/runs/detect/exp2"
for i in range (1,13):
  print('Число ступеней ' + str(sum(1 for line in open(path+'/labels/' + str(i) +'.txt', 'r'))))
  image = Image.open(path+'/'+str(i)+'.jpg')
  image = np.array(image)
  image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  cv2_imshow(image)

# %% [markdown]
# Детекция при conf = 0.3, на некоторых изображениях появились ошибки детекции
