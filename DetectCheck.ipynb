# %% [markdown]
# <a href="https://colab.research.google.com/github/Evgen-Shah/YOLOV5_WORKS/blob/main/DetectCheck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from PIL import Image
import numpy as np
import requests
from google.colab.patches import cv2_imshow
import inspect
import math
from math import sqrt
import imutils
from google.colab import drive
drive.mount('/content/drive')
from google.colab import files
from PIL import Image
from io import BytesIO
from IPython.display import display
# Out:
# Mounted at /content/drive

# %%
# !python /content/drive/MyDrive/contentShash/yolov5/train.py --img 640 --batch 16 --epochs 300 --data /content/drive/MyDrive/contentShash/yolov5/data/custom_date.yaml --weights /content/drive/MyDrive/contentShash/yolov5/yolov5s.pt --cache
# Out:
# train: weights=/content/drive/MyDrive/contentShash/yolov5/yolov5s.pt, cfg=, data=/content/drive/MyDrive/contentShash/yolov5/data/custom_date.yaml, hyp=drive/MyDrive/contentShash/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=drive/MyDrive/contentShash/yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 10 (delta 3), reused 6 (delta 3), pack-reused 0
# Unpacking objects: 100% (10/10), done.
# ...

# %%
# !python /content/drive/MyDrive/contentShash/yolov5/detect.py --weights /content/drive/MyDrive/contentShash/yolov5/runs/train/exp3/weights/last.pt --img 640 --conf 0.7 --source /content/drive/MyDrive/contentShash/yolov5/data/images --hide-labels --save-txt
# Out:
# detect: weights=['/content/drive/MyDrive/contentShash/yolov5/runs/train/exp3/weights/last.pt'], source=/content/drive/MyDrive/contentShash/yolov5/data/images, data=drive/MyDrive/contentShash/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.7, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=drive/MyDrive/contentShash/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=True, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-69-g7830e91 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7015519 parameters, 0 gradients
# image 1/9 /content/drive/MyDrive/contentShash/yolov5/data/images/1.png: 640x640 12 Ws, 12 Bs, Done. (0.349s)
# image 2/9 /content/drive/MyDrive/contentShash/yolov5/data/images/2.png: 640x640 12 Ws, 12 Bs, Done. (0.323s)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path="drive/MyDrive/contentShash/yolov5/runs/detect/exp11"
pathTxt="drive/MyDrive/contentShash/yolov5/runs/detect/exp11/labels"
for i in range(1,9):
  im = Image.open(path+'/'+str(i)+'.png')
  im = np.array(im)
  f = open(pathTxt + '/'+ str(i) +'.txt',"r")
  dh,dw, _ = im.shape
  for string in f:
         labe, x, y, w, h = map(float, string.split(' '))
         x = int((x - w / 2) * dw) # Координаты х для каждой шашки 
         w = int(w * dw)#
         y = int((y - h / 2) * dh)# Координаты у для каждой шашки 
         h = int(h * dh)#
         print(x,y)
         if (labe == 1):
            cv2.putText(im, str(x), (x,y),cv2.FONT_HERSHEY_SIMPLEX,1, (0, 0, 0), 1,cv2.LINE_AA  )
         elif (labe == 0):
            cv2.putText(im, str(x), (x,y),cv2.FONT_HERSHEY_SIMPLEX,1, (0, 0, 0), 1,cv2.LINE_AA  )
  im = cv2.cvtColor(im,cv2.COLOR_BGR2RGB)
  cv2_imshow(im)
# Out:
# 19 249
# 249 217
# 215 248
# 84 250
# 219 51
# 87 51
# 20 51
# 50 217
# 151 51
# 150 249
# 118 214
# 249 16
# 184 214
# 19 184
# 183 16
# 117 16
# 216 184
# 83 184
# 52 15
# 119 148
# 184 85
# 250 83
# 53 83
# 118 83
# <PIL.Image.Image image mode=RGB size=293x293 at 0x7F1A472F0190>
# 19 249
# 216 248
# 84 250
# 249 217
# 218 117
# 219 51
# 87 51
# 20 51
# 50 217
# 151 51
# 150 249
# 118 215
# 184 214
# 19 184
# 249 16
# 183 16
# 117 16
# 215 184
# 83 184
# 52 15
# 119 148
# 53 83
# 184 85
# 118 83
# <PIL.Image.Image image mode=RGB size=293x293 at 0x7F1A47281E10>
# 216 248
# 53 148
# 249 217
# 218 117
# 84 250
# 219 51
# 19 249
# 87 51
# 20 51
# 151 51
# 150 249
# 118 214
# 50 217
# 184 214
# 249 16
# 84 183
# 183 16
# 117 16
# 215 184
# 52 15
# 116 150
# 184 85
# 53 83
# 118 83
# <PIL.Image.Image image mode=RGB size=293x293 at 0x7F1A4728F7D0>
# 215 248
# 53 148
# 218 118
# 249 217
# 84 250
# 219 51
# 19 249
# 87 51
# 20 51
# 151 51
# 50 217
# 150 249
# 249 16
# 118 214
# 182 217
# ...
