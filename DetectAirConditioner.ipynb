# %% [markdown]
# <a href="https://colab.research.google.com/github/Evgen-Shah/YOLOV5_WORKS/blob/main/DetectAirConditioner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Подключим необходимые библиотеки

# %%
import cv2
from PIL import Image
import numpy as np
import requests
from google.colab.patches import cv2_imshow
import inspect
import math
from math import sqrt
import imutils
from google.colab import drive
drive.mount('/content/drive')
from google.colab import files
from PIL import Image
from io import BytesIO
from IPython.display import display
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Загрузим изображения для обучения

# %%
import os.path
path="/content/drive/MyDrive/CondImages"
num_files = sum(os.path.isfile(os.path.join(path, f)) for f in os.listdir(path)) 
for i in range (1,num_files):
  image = Image.open(path+'/'+str(i)+'.jpg')
  image = np.array(image)
  image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  cv2_imshow(image)

# %% [markdown]
# Выведем изображения с выдлененными объектами для обучения

# %%
path="/content/drive/MyDrive/contentCond/yolov5/runs/train/exp11"
ai = Image.open(path+'/train_batch2.jpg')
display(ai)
ai = Image.open(path+'/train_batch1.jpg')
display(ai)
ai = Image.open(path+'/train_batch0.jpg')
display(ai)

# %% [markdown]
# # Обучим нейронную сеть на 250 эпохах с 16 батчами

# %%
# !python /content/drive/MyDrive/contentCond/yolov5/train.py --img 640 --batch 16 --epochs 250 --data /content/drive/MyDrive/contentCond/yolov5/data/custom.yaml --weights /content/drive/MyDrive/contentCond/yolov5/yolov5s.pt --cache
# Out:
# train: weights=/content/drive/MyDrive/contentCond/yolov5/yolov5s.pt, cfg=, data=/content/drive/MyDrive/contentCond/yolov5/data/custom.yaml, hyp=drive/MyDrive/contentCond/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=250, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=drive/MyDrive/contentCond/yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 36 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-69-g7830e91 torch 1.10.0+cu111 CPU
#
# ...

# %% [markdown]
# # Проведем детекцию изображений с разными параметрами уверенности определения

# %% [markdown]
# conf = 0.5

# %%
# !python /content/drive/MyDrive/contentCond/yolov5/detect.py --weights /content/drive/MyDrive/contentCond/yolov5/runs/train/exp11/weights/last.pt --img 640 --conf 0.5 --source /content/drive/MyDrive/contentCond/yolov5/data/images --save-txt
# Out:
# detect: weights=['/content/drive/MyDrive/contentCond/yolov5/runs/train/exp11/weights/last.pt'], source=/content/drive/MyDrive/contentCond/yolov5/data/images, data=drive/MyDrive/contentCond/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=drive/MyDrive/contentCond/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-69-g7830e91 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/11 /content/drive/MyDrive/contentCond/yolov5/data/images/1.jpg: 480x640 65 conds, Done. (0.290s)
# image 2/11 /content/drive/MyDrive/contentCond/yolov5/data/images/10.jpg: 352x640 11 conds, Done. (0.200s)
# ...

# %%
import os.path
path="/content/drive/MyDrive/contentCond/yolov5/runs/detect/exp"
num_files = sum(os.path.isfile(os.path.join(path, f)) for f in os.listdir(path)) 
for i in range (1,num_files):
  image = Image.open(path+'/'+str(i)+'.jpg')
  print('Найденных кондиционеров ' + str(sum(1 for line in open(path+'/labels/' + str(i) +'.txt', 'r'))))
  image = np.array(image)
  image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  cv2_imshow(image)

# %% [markdown]
# conf = 0.6

# %%
# !python /content/drive/MyDrive/contentCond/yolov5/detect.py --weights /content/drive/MyDrive/contentCond/yolov5/runs/train/exp11/weights/last.pt --img 640 --conf 0.6 --source /content/drive/MyDrive/contentCond/yolov5/data/images --save-txt
# Out:
# detect: weights=['/content/drive/MyDrive/contentCond/yolov5/runs/train/exp11/weights/last.pt'], source=/content/drive/MyDrive/contentCond/yolov5/data/images, data=drive/MyDrive/contentCond/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.6, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=drive/MyDrive/contentCond/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-69-g7830e91 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/11 /content/drive/MyDrive/contentCond/yolov5/data/images/1.jpg: 480x640 43 conds, Done. (0.425s)
# image 2/11 /content/drive/MyDrive/contentCond/yolov5/data/images/10.jpg: 352x640 8 conds, Done. (0.243s)
# ...

# %%
import os.path
path="/content/drive/MyDrive/contentCond/yolov5/runs/detect/exp3"
num_files = sum(os.path.isfile(os.path.join(path, f)) for f in os.listdir(path)) 
for i in range (1,num_files):
  print('Найденных кондиционеров ' + str(sum(1 for line in open(path+'/labels/' + str(i) +'.txt', 'r'))))
  image = Image.open(path+'/'+str(i)+'.jpg')
  image = np.array(image)
  image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  cv2_imshow(image)

# %% [markdown]
# conf = 0.7

# %%
# !python /content/drive/MyDrive/contentCond/yolov5/detect.py --weights /content/drive/MyDrive/contentCond/yolov5/runs/train/exp11/weights/last.pt --img 640 --conf 0.7 --source /content/drive/MyDrive/contentCond/yolov5/data/images --save-txt
# Out:
# detect: weights=['/content/drive/MyDrive/contentCond/yolov5/runs/train/exp11/weights/last.pt'], source=/content/drive/MyDrive/contentCond/yolov5/data/images, data=drive/MyDrive/contentCond/yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.7, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=drive/MyDrive/contentCond/yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-69-g7830e91 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7012822 parameters, 0 gradients
# image 1/11 /content/drive/MyDrive/contentCond/yolov5/data/images/1.jpg: 480x640 24 conds, Done. (0.352s)
# image 2/11 /content/drive/MyDrive/contentCond/yolov5/data/images/10.jpg: 352x640 6 conds, Done. (0.234s)
# ...

# %%
import os.path
path="/content/drive/MyDrive/contentCond/yolov5/runs/detect/exp5"
num_files = sum(os.path.isfile(os.path.join(path, f)) for f in os.listdir(path)) 
for i in range (1,num_files):
  print('Найденных кондиционеров ' + str(sum(1 for line in open(path+'/labels/' + str(i) +'.txt', 'r'))))
  image = Image.open(path+'/'+str(i)+'.jpg')
  image = np.array(image)
  image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
  cv2_imshow(image)
